# %% [markdown]
# #VODHALA SANTOSH

# %% [markdown]
# #Lets Grow More - Data Science Internship

# %% [markdown]
# #TASK - 1
# #Image to Pencil Sketch with Python

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2 # importing opencv library packages

# %%
image=cv2.imread("/content/jocker.jpg")

# %%
cv2_imshow(image) # Displaying the original image
# Out:
# <PIL.Image.Image image mode=RGB size=270x480 at 0x7F6B80E61050>

# %%
img_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # Original image ------>> Grayscale

# %%
cv2_imshow(img_gray)# Displaying the grayscale  image
# Out:
# <PIL.Image.Image image mode=L size=270x480 at 0x7F6B81ECAFD0>

# %%
img_invert=cv2.bitwise_not(img_gray) # Grayscale ------>> Negative

# %%
cv2_imshow(img_invert) # Displaying the  Negative  image
# Out:
# <PIL.Image.Image image mode=L size=270x480 at 0x7F6B81ED0950>

# %%
img_smooth=cv2.GaussianBlur(img_invert,(21,21),sigmaX=0,sigmaY=0) # Negative ------>> Blur image

# %%
cv2_imshow(img_smooth) # Displaying the  blur image
# Out:
# <PIL.Image.Image image mode=L size=270x480 at 0x7F6B81ED0B90>

# %%
def dodgeV2(x,y):
  return cv2.divide(x,255-y,scale=256)

# %%
final_img=dodgeV2(img_gray,img_smooth) #Dividing the grayscale image by the inverted blurry image since images are just arrays

# %%
cv2_imshow(final_img) # Displaying the  final sketch image
# Out:
# <PIL.Image.Image image mode=L size=270x480 at 0x7F6B80E730D0>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=270x480 at 0x7F6B81ECA110>

# %%
cv2_imshow(final_img) # Displaying the original and the final sketch image
# Out:
# <PIL.Image.Image image mode=L size=270x480 at 0x7F6B81ED0A90>
